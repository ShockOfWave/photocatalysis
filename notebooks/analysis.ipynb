# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv('../data/processed/data.csv')

# %%
df
# Out:
#     Прекурсор   Добавка  Метод нанесения pt  \
# 0            1        0                   0
# 1            0        0                   0
# 2            1        0                   0
# 3            0        0                   0
# 4            1        0                   0
# ..         ...      ...                 ...
# 60           9        0                   0
# 61          10        0                   0
# 62          11        0                   0
# 63          12        0                   0
# 64          14        0                   0
#
#     Температура восстановления комплекса платины (°С)  Содержание [%]  \
# 0                                                   0             1.0
# 1                                                   0             1.0
# 2                                                   0             1.0
# 3                                                   0             1.0
# 4                                                   0             3.0
# ...

# %%
matrix = df.corr().round(2)
mask = np.triu(np.ones_like(df.corr().round(2)))
fig, ax = plt.subplots(figsize=(14, 14))
sns.heatmap(matrix, annot=True, ax=ax, cmap='Blues', mask=mask)
ax.set_title('Correlation matrix')
fig.tight_layout()
fig.savefig('../reports/figures/correlation_matrix.svg', format='svg', dpi=1200)

# %%
df.describe().to_csv('../reports/tables/data_describe.csv', index=False)
df.describe()
# Out:
#        Прекурсор     Добавка  Метод нанесения pt  \
# count   65.000000  65.000000           65.000000
# mean     4.953846   0.153846            0.846154
# std      5.856169   0.441261            1.348967
# min      0.000000   0.000000            0.000000
# 25%      1.000000   0.000000            0.000000
# 50%      2.000000   0.000000            0.000000
# 75%     10.000000   0.000000            2.000000
# max     15.000000   2.000000            4.000000
#
#        Температура восстановления комплекса платины (°С)  Содержание [%]  \
# count                                          65.000000       65.000000
# mean                                           90.769231        1.155692
# std                                           166.511145        0.940492
# min                                             0.000000        0.000000
# 25%                                             0.000000        0.500000
# 50%                                             0.000000        1.000000
# ...

# %%
df['XRD1 2theta'].hist()
plt.title('Histogram XRD1 2theta')
plt.ylabel('Num features')
plt.xlabel('Feature value')
plt.tight_layout()
plt.savefig('../reports/figures/histogram_xrd1_2theta.svg', format='svg', dpi=1200)

# %%
df['XRD2 2theta'].hist()
plt.title('Histogram XRD2 2theta')
plt.ylabel('Num features')
plt.xlabel('Feature value')
plt.tight_layout()
plt.savefig('../reports/figures/histogram_xrd2_2theta.svg', format='svg', dpi=1200)

# %%
df['SBET [m^2/g]'].hist()
plt.title('Histogram SBET [m^2/g]')
plt.ylabel('Num features')
plt.xlabel('Feature value')
plt.tight_layout()
plt.savefig('../reports/figures/histogram_sbet.svg', format='svg', dpi=1200)

# %%
df['Catalytic activity [μmol/ (g*h)]'].hist()
plt.title('Histogram Catalytic activity [μmol/ (g*h)]')
plt.ylabel('Num features')
plt.xlabel('Feature value')
plt.tight_layout()
plt.savefig('../reports/figures/histogram_cat_act_umol_g_h.svg', format='svg', dpi=1200)

# %%
df['Catalytic activity [μmol/(m^2*h)]'].hist()
plt.title('Histogram Catalytic activity [μmol/(m^2*h)]')
plt.ylabel('Num features')
plt.xlabel('Feature value')
plt.tight_layout()
plt.savefig('../reports/figures/histogram_cat_act_umol_m2_h.svg', format='svg', dpi=1200)
